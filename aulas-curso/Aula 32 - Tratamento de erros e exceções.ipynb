# %% [markdown]
# # Tratamento de erros e exceções
#
# - NameError: variável nao foi definida
# - TypeError: tipos de dados incompatíveis
# - RuntimeError: erro de execução
# - SyntaxError: sintaxe digitada é inválida e não reconhecida pelo interpretador
# - ZeroDivisionError: divisão por zero
# - IndexError: índice está fora da coleção

# %% [markdown]
# ## Tipos de erros

# %%
3 = 4
# Out:
#   File "/tmp/ipykernel_44627/732916017.py", line 1
#     3 = 4
#     ^
# SyntaxError: cannot assign to literal

# %%
print('Meu nome é', nome)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_44627/3090556206.py in <module>
# ----> 1 print('Meu nome é', nome)
#
# NameError: name 'nome' is not defined

# %%
print(3 / 0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_44627/1606758863.py in <module>
# ----> 1 print(3 / 0)
#
# ZeroDivisionError: division by zero

# %%
2.3 / 'cachorro'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_44627/3281883994.py in <module>
# ----> 1 2.3 / 'cachorro'
#
# TypeError: unsupported operand type(s) for /: 'float' and 'str'

# %%
c = [1, 2, 3, 4, 5]
c
# Out:
# [1, 2, 3, 4, 5]

# %%
c[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_44627/2202566835.py in <module>
# ----> 1 c[5]
#
# IndexError: list index out of range

# %% [markdown]
# ## Tratamento de erros

# %%
try:
    n = int(input('Digite um número inteiro: '))
except:
    print('Valor inválido')
else:
    print(f'Valor digitado é {n}')
# Out:
# Valor inválido

# %%
while True:
    try:
        n = int(input('Digite um número inteiro: '))
    except:
        print('Valor inválido')
    else:
        print(f'Valor digitado é {n}')
        break
# Out:
# Valor digitado é 5

# %%
while True:
    try:
        p = int(input('Digite um número inteiro'))
    except ValueError:
        print('Valor inválido')
    except KeyboardInterrupt:
        print('Usuário interrompeu a execução')
        break
    else:
        print(f'Valor digitado é {p}')
        break
# Out:
# Valor inválido
# Valor digitado é 9
