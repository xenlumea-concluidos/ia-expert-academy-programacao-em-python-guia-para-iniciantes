# %% [markdown]
# # Módulos personalizados

# %%
import utilitarios as ut

# %%
ut.soma(1, 2, 3)
# Out:
# 6

# %%
ut.mult(3, 2, 2)
# Out:
# 12

# %%
ut.isPalindromo('abc')
# Out:
# False

# %%
ut.isPalindromo('abccba')
# Out:
# True

# %%
t = 'abccba'

# %%
t[::-1]
# Out:
# 'abccba'

# %%
t1 = 'abc'
t1[::-1]
# Out:
# 'cba'

# %%
ut.divisao(10, 2)
# Out:
# 5.0
